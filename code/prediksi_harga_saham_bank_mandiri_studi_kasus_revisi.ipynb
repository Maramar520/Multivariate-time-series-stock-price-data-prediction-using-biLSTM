# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Dense, Dropout, Bidirectional, Flatten
import pandas as pd
import math
import numpy as np
import seaborn as sns
import tensorflow as tf
from matplotlib import pyplot as plt
from datetime import timedelta
from keras.models import load_model

# %%
# Set random seed for reproducibility
tf.random.set_seed(1234)

# %% [markdown]
# # Pengambilan Data

# %%
# Data Bank
file = 'stock_dataset/BMRI.JK.csv'
df = pd.read_csv(file, parse_dates = True,index_col=0)
df
# Out:
#               Open    High     Low   Close    Adj Close      Volume
# Date
# 2015-01-02  5387.5  5425.0  5375.0  5412.5  4291.285645  42273400.0
# 2015-01-05  5425.0  5425.0  5375.0  5400.0  4281.375000  16681600.0
# 2015-01-06  5375.0  5412.5  5337.5  5362.5  4251.643555  29300000.0
# 2015-01-07  5375.0  5425.0  5362.5  5425.0  4301.195313  25122200.0
# 2015-01-08  5450.0  5487.5  5437.5  5475.0  4340.839355  31824800.0
# ...            ...     ...     ...     ...          ...         ...
# 2021-12-15  7150.0  7325.0  7125.0  7275.0  7275.000000  37838700.0
# 2021-12-16  7300.0  7325.0  7200.0  7250.0  7250.000000  34541200.0
# 2021-12-17  7225.0  7225.0  7075.0  7150.0  7150.000000  41972600.0
# 2021-12-20  7100.0  7150.0  7075.0  7075.0  7075.000000  28966300.0
# 2021-12-21  7150.0  7250.0  7100.0  7150.0  7150.000000  24929800.0
#
# [1746 rows x 6 columns]

# %%
# Data Kurs Rupiah
file = 'stock_dataset/Kurs_Transaksi_USD.csv'
df1 = pd.read_csv(file, parse_dates = True,index_col=0)
df1
# Out:
#             Nilai  Kurs Jual  Kurs Beli
# Date
# 2015-01-02      1   12536.00   12412.00
# 2015-01-05      1   12652.00   12526.00
# 2015-01-06      1   12721.00   12595.00
# 2015-01-07      1   12796.00   12668.00
# 2015-01-08      1   12795.00   12667.00
# ...           ...        ...        ...
# 2021-12-15      1   14419.74   14276.26
# 2021-12-16      1   14408.69   14265.32
# 2021-12-17      1   14414.72   14271.29
# 2021-12-20      1   14414.72   14271.29
# 2021-12-21      1   14455.92   14312.08
#
# [1719 rows x 3 columns]

# %% [markdown]
# # Preprocessing Data

# %%
# menggabungkan data kurs dan data harga saham 
data = pd.merge_asof(df, df1, on='Date')
data = data.rename(columns = {'Adj Close' : 'adj_close', 'Kurs Jual' : 'kurs_jual', 'Kurs Beli' : 'kurs_beli'})
dataset = data.set_index('Date')
dataset
# Out:
#               Open    High     Low   Close    adj_close      Volume  Nilai  \
# Date
# 2015-01-02  5387.5  5425.0  5375.0  5412.5  4291.285645  42273400.0      1
# 2015-01-05  5425.0  5425.0  5375.0  5400.0  4281.375000  16681600.0      1
# 2015-01-06  5375.0  5412.5  5337.5  5362.5  4251.643555  29300000.0      1
# 2015-01-07  5375.0  5425.0  5362.5  5425.0  4301.195313  25122200.0      1
# 2015-01-08  5450.0  5487.5  5437.5  5475.0  4340.839355  31824800.0      1
# ...            ...     ...     ...     ...          ...         ...    ...
# 2021-12-15  7150.0  7325.0  7125.0  7275.0  7275.000000  37838700.0      1
# 2021-12-16  7300.0  7325.0  7200.0  7250.0  7250.000000  34541200.0      1
# 2021-12-17  7225.0  7225.0  7075.0  7150.0  7150.000000  41972600.0      1
# 2021-12-20  7100.0  7150.0  7075.0  7075.0  7075.000000  28966300.0      1
# 2021-12-21  7150.0  7250.0  7100.0  7150.0  7150.000000  24929800.0      1
#
#             kurs_jual  kurs_beli
# Date
# 2015-01-02   12536.00   12412.00
# 2015-01-05   12652.00   12526.00
# 2015-01-06   12721.00   12595.00
# 2015-01-07   12796.00   12668.00
# 2015-01-08   12795.00   12667.00
# ...               ...        ...
# 2021-12-15   14419.74   14276.26
# 2021-12-16   14408.69   14265.32
# 2021-12-17   14414.72   14271.29
# 2021-12-20   14414.72   14271.29
# 2021-12-21   14455.92   14312.08
#
# [1746 rows x 9 columns]

# %%
# Periksa nilai yang hilang
data.isnull().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# adj_close    1
# Volume       1
# Nilai        0
# kurs_jual    0
# kurs_beli    0
# dtype: int64

# %%
nul_data = pd.isnull(dataset['Close']) 
dataset[nul_data]
# Out:
#             Open  High  Low  Close  adj_close  Volume  Nilai  kurs_jual  \
# Date
# 2019-06-19   NaN   NaN  NaN    NaN        NaN     NaN      1    14342.0
#
#             kurs_beli
# Date
# 2019-06-19    14200.0

# %%
# Ganti nilai yang hilang dengan interpolasi
dataset = dataset.fillna(dataset.interpolate(method='linear'))
dataset.to_csv("stock_dataset/data_cleaning_bm.csv", index=True)
dataset.loc[["2019-06-19"]]
# Out:
#               Open    High     Low   Close  adj_close      Volume  Nilai  \
# Date
# 2019-06-19  7887.5  7962.5  7850.0  7900.0  7272.0542  49423850.0      1
#
#             kurs_jual  kurs_beli
# Date
# 2019-06-19    14342.0    14200.0

# %%
dataset = dataset.reset_index()
dataset
# Out:
#            Date    Open    High     Low   Close    adj_close      Volume  \
# 0    2015-01-02  5387.5  5425.0  5375.0  5412.5  4291.285645  42273400.0
# 1    2015-01-05  5425.0  5425.0  5375.0  5400.0  4281.375000  16681600.0
# 2    2015-01-06  5375.0  5412.5  5337.5  5362.5  4251.643555  29300000.0
# 3    2015-01-07  5375.0  5425.0  5362.5  5425.0  4301.195313  25122200.0
# 4    2015-01-08  5450.0  5487.5  5437.5  5475.0  4340.839355  31824800.0
# ...         ...     ...     ...     ...     ...          ...         ...
# 1741 2021-12-15  7150.0  7325.0  7125.0  7275.0  7275.000000  37838700.0
# 1742 2021-12-16  7300.0  7325.0  7200.0  7250.0  7250.000000  34541200.0
# 1743 2021-12-17  7225.0  7225.0  7075.0  7150.0  7150.000000  41972600.0
# 1744 2021-12-20  7100.0  7150.0  7075.0  7075.0  7075.000000  28966300.0
# 1745 2021-12-21  7150.0  7250.0  7100.0  7150.0  7150.000000  24929800.0
#
#       Nilai  kurs_jual  kurs_beli
# 0         1   12536.00   12412.00
# 1         1   12652.00   12526.00
# 2         1   12721.00   12595.00
# 3         1   12796.00   12668.00
# 4         1   12795.00   12667.00
# ...     ...        ...        ...
# 1741      1   14419.74   14276.26
# 1742      1   14408.69   14265.32
# 1743      1   14414.72   14271.29
# 1744      1   14414.72   14271.29
# 1745      1   14455.92   14312.08
#
# [1746 rows x 10 columns]

# %%
# Korelasi Data
dataset.drop(['Nilai'], axis=1, inplace=True)
matrix = dataset.corr(method='pearson')
ax = sns.heatmap(matrix, vmax=1, vmin=-1, annot=True)
ax.figure.savefig('M:/Metopen/save/korelasi_mr.jpg')

# %%
# pemilihan fitur
df = read_csv('stock_dataset/data_cleaning_bm.csv', header=0, index_col=0)
df.drop(['Volume', 'Nilai', 'kurs_jual', 'kurs_beli'], axis=1, inplace=True)
df
# Out:
#               Open    High     Low   Close    adj_close
# Date
# 2015-01-02  5387.5  5425.0  5375.0  5412.5  4291.285645
# 2015-01-05  5425.0  5425.0  5375.0  5400.0  4281.375000
# 2015-01-06  5375.0  5412.5  5337.5  5362.5  4251.643555
# 2015-01-07  5375.0  5425.0  5362.5  5425.0  4301.195313
# 2015-01-08  5450.0  5487.5  5437.5  5475.0  4340.839355
# ...            ...     ...     ...     ...          ...
# 2021-12-15  7150.0  7325.0  7125.0  7275.0  7275.000000
# 2021-12-16  7300.0  7325.0  7200.0  7250.0  7250.000000
# 2021-12-17  7225.0  7225.0  7075.0  7150.0  7150.000000
# 2021-12-20  7100.0  7150.0  7075.0  7075.0  7075.000000
# 2021-12-21  7150.0  7250.0  7100.0  7150.0  7150.000000
#
# [1746 rows x 5 columns]

# %%
# pindah kolom baris close ke baris pertama
last_col = df.pop('Close')
type(last_col)
pd.core.series.Series
df.insert(loc=0, column = 'Close', value = last_col)
df
# Out:
#              Close    Open    High     Low    adj_close
# Date
# 2015-01-02  5412.5  5387.5  5425.0  5375.0  4291.285645
# 2015-01-05  5400.0  5425.0  5425.0  5375.0  4281.375000
# 2015-01-06  5362.5  5375.0  5412.5  5337.5  4251.643555
# 2015-01-07  5425.0  5375.0  5425.0  5362.5  4301.195313
# 2015-01-08  5475.0  5450.0  5487.5  5437.5  4340.839355
# ...            ...     ...     ...     ...          ...
# 2021-12-15  7275.0  7150.0  7325.0  7125.0  7275.000000
# 2021-12-16  7250.0  7300.0  7325.0  7200.0  7250.000000
# 2021-12-17  7150.0  7225.0  7225.0  7075.0  7150.000000
# 2021-12-20  7075.0  7100.0  7150.0  7075.0  7075.000000
# 2021-12-21  7150.0  7150.0  7250.0  7100.0  7150.000000
#
# [1746 rows x 5 columns]

# %%
# pastikan semua data bertipe float
values = df.values
values = values.astype('float32')
values

# normalisasi fitur
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
scaled
# Out:
# array([[0.31754214, 0.3309524 , 0.30952376, 0.34782606, 0.27096653],
#        [0.31519693, 0.3380952 , 0.30952376, 0.34782606, 0.2688269 ],
#        [0.30816132, 0.32857144, 0.3071428 , 0.3405797 , 0.26240808],
#        ...,
#        [0.6435272 , 0.6809523 , 0.6523809 , 0.6763285 , 0.88814   ],
#        [0.62945586, 0.6571429 , 0.6380952 , 0.6763285 , 0.87194806],
#        [0.6435272 , 0.6666666 , 0.6571428 , 0.68115944, 0.88814   ]],
#       dtype=float32)

# %%
# konversi series ke supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# frame sebagai supervised learning
ref = series_to_supervised(scaled, 1, 1)
ref
# Out:
#       var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)  \
# 1      0.317542   0.330952   0.309524   0.347826   0.270967  0.315197
# 2      0.315197   0.338095   0.309524   0.347826   0.268827  0.308161
# 3      0.308161   0.328571   0.307143   0.340580   0.262408  0.319887
# 4      0.319887   0.328571   0.309524   0.345411   0.273106  0.329268
# 5      0.329268   0.342857   0.321429   0.359903   0.281665  0.345685
# ...         ...        ...        ...        ...        ...       ...
# 1741   0.648218   0.661905   0.647619   0.681159   0.893537  0.666979
# 1742   0.666979   0.666667   0.671429   0.685990   0.915127  0.662289
# 1743   0.662289   0.695238   0.671429   0.700483   0.909729  0.643527
# 1744   0.643527   0.680952   0.652381   0.676328   0.888140  0.629456
# 1745   0.629456   0.657143   0.638095   0.676328   0.871948  0.643527
#
#        var2(t)   var3(t)   var4(t)   var5(t)
# 1     0.338095  0.309524  0.347826  0.268827
# 2     0.328571  0.307143  0.340580  0.262408
# 3     0.328571  0.309524  0.345411  0.273106
# 4     0.342857  0.321429  0.359903  0.281665
# 5     0.352381  0.345238  0.367150  0.296642
# ...        ...       ...       ...       ...
# 1741  0.666667  0.671429  0.685990  0.915127
# 1742  0.695238  0.671429  0.700483  0.909729
# 1743  0.680952  0.652381  0.676328  0.888140
# 1744  0.657143  0.638095  0.676328  0.871948
# 1745  0.666667  0.657143  0.681159  0.888140
#
# [1745 rows x 10 columns]

# %%
# drop kolom yang tidak ingin diprediksi
ref.drop(ref.columns[[6,7,8,9]], axis=1, inplace=True)
ref.to_csv("stock_dataset/normalisasi_bm.csv", index=False)
ref
# Out:
#       var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# 1      0.317542   0.330952   0.309524   0.347826   0.270967  0.315197
# 2      0.315197   0.338095   0.309524   0.347826   0.268827  0.308161
# 3      0.308161   0.328571   0.307143   0.340580   0.262408  0.319887
# 4      0.319887   0.328571   0.309524   0.345411   0.273106  0.329268
# 5      0.329268   0.342857   0.321429   0.359903   0.281665  0.345685
# ...         ...        ...        ...        ...        ...       ...
# 1741   0.648218   0.661905   0.647619   0.681159   0.893537  0.666979
# 1742   0.666979   0.666667   0.671429   0.685990   0.915127  0.662289
# 1743   0.662289   0.695238   0.671429   0.700483   0.909729  0.643527
# 1744   0.643527   0.680952   0.652381   0.676328   0.888140  0.629456
# 1745   0.629456   0.657143   0.638095   0.676328   0.871948  0.643527
#
# [1745 rows x 6 columns]

# %%
# pembagian data pelatihan dan pengujian
values = ref.values

train_size = 0.8
valid_size=0.1

train_index = int(len(values)*train_size)

train = values[0:train_index]
rem = values[train_index:]

valid_index = int(len(values)*valid_size)

valid = values[train_index:train_index+valid_index]
test = values[train_index+valid_index:]

print(train.shape, valid.shape, test.shape)
# Out:
# (1396, 6) (174, 6) (175, 6)

# %%
# membuat dataset
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
valid_X, valid_y = valid[:, :-1], valid[:, -1]

# reshape masukan menjadi 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
valid_X = valid_X.reshape((valid_X.shape[0], 1, valid_X.shape[1]))
print(train_X.shape, train_y.shape, valid_X.shape, valid_y.shape, test_X.shape, test_y.shape)
# Out:
# (1396, 1, 5) (1396,) (174, 1, 5) (174,) (175, 1, 5) (175,)

# %% [markdown]
# # Perancangan dan Pelatihan Model biLSTM

# %%
# membuat rancangan model
model = Sequential()
# bidirectinal layer
model.add(Bidirectional(LSTM(30, return_sequences=True),input_shape=(train_X.shape[1], train_X.shape[2])))
# fully connected layer
model.add(Flatten())
model.add(Dense(40, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
opt = tf.keras.optimizers.Adam()
model.compile(loss='mse', optimizer= opt, metrics=[tf.keras.metrics.RootMeanSquaredError()])
model.summary()
# pelatihan model
history = model.fit(train_X, train_y, batch_size= 250, epochs= 500, validation_data=(valid_X, valid_y), verbose=0, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')
pyplot.savefig('M:/Metopen/save/loss_mr.jpg', format='jpg', dpi=1000)
pyplot.legend()
pyplot.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 1, 60)            8640
#  l)
#
#  flatten (Flatten)           (None, 60)                0
#
#  dense (Dense)               (None, 40)                2440
#
#  dropout (Dropout)           (None, 40)                0
#
#  dense_1 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 11,121
# Trainable params: 11,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot model
import keras.utils.vis_utils
from importlib import reload
reload(keras.utils.vis_utils)


from keras.utils.vis_utils import plot_model    
plot_model(model, to_file='M:/Metopen/save/model_mandiri.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Evaluasi Model

# %%
# evaluasi model dengan data pengujian
evaluasi = model.evaluate(test_X, test_y)
print("test loss:", "test metrics:", evaluasi)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 5.6408e-04 - root_mean_squared_error: 0.0238
# test loss: test metrics: [0.0005640790332108736, 0.023750348016619682]

# %%
# evaluasi model dengan data pengujian
evaluasi = model.evaluate(train_X, train_y)
print("test loss:", "test metrics:", evaluasi)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 5.5927e-04 - root_mean_squared_error: 0.0236
# test loss: test metrics: [0.0005592727684415877, 0.023648949339985847]

# %%
model.save('M:/Metopen/save/model_mandiri.h5')
model.save_weights('M:/Metopen/save/model_weights_mandiri.h5')

# %% [markdown]
# # Prediksi Data

# %%
# load model
model = load_model('M:/Metopen/save/model_mandiri.h5')
model.load_weights('M:/Metopen/save/model_weights_mandiri.h5')


# load data bank BRI baru
df = read_csv('stock_dataset/BMRI.JK_revisi.csv', parse_dates = True, index_col=0)
dataset = df.reset_index()

# %%
data = dataset.set_index('Date')
last_col = data.pop('Close')
type(last_col)
pd.core.series.Series
data.insert(loc=0, column = 'Close', value = last_col)
data
# Out:
#             Close  Open  High   Low    Adj Close
# Date
# 2021-12-22   7050  7175  7200  7050  6729.182129
# 2021-12-23   7075  7050  7150  7050  6753.044434
# 2021-12-24   7050  7100  7150  6950  6729.182129
# 2021-12-27   7000  7050  7100  6975  6681.457520
# 2021-12-28   7050  7050  7050  6975  6729.182129
# ...           ...   ...   ...   ...          ...
# 2022-08-24   8625  8600  8700  8550  8625.000000
# 2022-08-25   8575  8550  8625  8425  8575.000000
# 2022-08-26   8500  8625  8650  8500  8500.000000
# 2022-08-29   8550  8400  8600  8350  8550.000000
# 2022-08-30   8650  8625  8750  8575  8650.000000
#
# [165 rows x 5 columns]

# %%
data.describe()
# Out:
#              Close         Open         High          Low    Adj Close
# count   165.000000   165.000000   165.000000   165.000000   165.000000
# mean   7827.121212  7827.272727  7913.484848  7735.151515  7705.751024
# std     443.683704   434.934273   453.370650   425.384483   556.991766
# min    7000.000000  7025.000000  7050.000000  6925.000000  6681.457520
# 25%    7550.000000  7575.000000  7650.000000  7450.000000  7301.878418
# 50%    7850.000000  7825.000000  7900.000000  7750.000000  7725.000000
# 75%    8175.000000  8175.000000  8250.000000  8025.000000  8175.000000
# max    8950.000000  8775.000000  9075.000000  8675.000000  8950.000000

# %%
# normalisasi data uji baru
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(data)

# konversi data uji baru
ref = series_to_supervised(scaled, 1, 1)
ref.drop(ref.columns[[6,7,8,9]], axis=1, inplace=True)
ref
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# 1     0.025641   0.085714   0.074074   0.071429   0.021038  0.038462
# 2     0.038462   0.014286   0.049383   0.071429   0.031556  0.025641
# 3     0.025641   0.042857   0.049383   0.014286   0.021038  0.000000
# 4     0.000000   0.014286   0.024691   0.028571   0.000000  0.025641
# 5     0.025641   0.014286   0.000000   0.028571   0.021038  0.051282
# ..         ...        ...        ...        ...        ...       ...
# 160   0.833333   0.842857   0.802469   0.871429   0.856736  0.833333
# 161   0.833333   0.900000   0.814815   0.928571   0.856736  0.807692
# 162   0.807692   0.871429   0.777778   0.857143   0.834696  0.769231
# 163   0.769231   0.914286   0.790123   0.900000   0.801635  0.794872
# 164   0.794872   0.785714   0.765432   0.814286   0.823675  0.846154
#
# [164 rows x 6 columns]

# %%
# membuat dataset 
values = ref.values
new_test_X, new_test_y = values[:, :-1], values[:, -1]
new_test_X = new_test_X.reshape((new_test_X.shape[0], 1, new_test_X.shape[1]))
print(new_test_X.shape, new_test_y.shape)
# Out:
# (164, 1, 5) (164,)

# %%
# membuat prediksi dengan data yang baru 
predict = model.predict(new_test_X)
new_test_X = new_test_X.reshape((new_test_X.shape[0], new_test_X.shape[2]))
# denormalisasi untuk data prediksi
inv_predict = concatenate((predict, new_test_X[:, 1:]), axis=1)
inv_predict = scaler.inverse_transform(inv_predict)
inv_predict = inv_predict[:, 0]
# denormalisasi untuk data aktual
new_test_y = new_test_y.reshape((len(new_test_y), 1))
inv_actual = concatenate((new_test_y, new_test_X[:, 1:]), axis=1)
inv_actual = scaler.inverse_transform(inv_actual)
inv_actual = inv_actual[:,0]

# %%
# hasil prediksi sebelum denormalisasi
predict
# Out:
# array([[0.05590892],
#        [0.07779789],
#        [0.05180383],
#        [0.03844929],
#        [0.04993778],
#        [0.07493687],
#        [0.04724258],
#        [0.05598468],
#        [0.11554259],
#        [0.03609809],
#        [0.03806436],
#        [0.06440499],
#        [0.05921867],
#        [0.05062616],
#        [0.1043624 ],
#        [0.08818761],
#        [0.12112886],
#        [0.1169976 ],
#        [0.13839757],
#        [0.04232696],
#        [0.10616702],
#        [0.1654379 ],
#        [0.14562096],
#        [0.13068485],
#        [0.24416257],
#        [0.2818784 ],
#        [0.32176745],
#        [0.23408465],
#        [0.24126461],
#        [0.23086157],
#        [0.24727914],
#        [0.2503239 ],
#        [0.32624924],
#        [0.33601502],
#        [0.3612373 ],
#        [0.35670406],
#        [0.3870276 ],
#        [0.43653834],
#        [0.43977684],
#        [0.4218673 ],
#        [0.44034213],
#        [0.45293868],
#        [0.44549528],
#        [0.4613465 ],
#        [0.37048903],
#        [0.35025385],
#        [0.35458413],
#        [0.31814197],
#        [0.32619536],
#        [0.28540117],
#        [0.28961748],
#        [0.3333923 ],
#        [0.33949143],
#        [0.32212222],
#        [0.37843522],
#        [0.4106015 ],
#        [0.480373  ],
#        [0.5100659 ],
#        [0.485503  ],
#        [0.32492045],
#        [0.33904162],
#        [0.38032684],
#        [0.44423756],
#        [0.4471015 ],
#        [0.44764793],
#        [0.48649085],
#        [0.46403316],
#        [0.47002912],
#        [0.44460532],
#        [0.42836815],
#        [0.4286485 ],
#        [0.32959405],
#        [0.35207063],
#        [0.34269115],
#        [0.33904162],
#        [0.34871405],
#        [0.360115  ],
#        [0.33500284],
#        [0.3118031 ],
#        [0.2937209 ],
#        [0.40743402],
#        [0.6199905 ],
#        [0.6337075 ],
#        [0.62621826],
#        [0.6827631 ],
#        [0.65254146],
#        [0.9789142 ],
#        [0.7257185 ],
#        [0.53282416],
#        [0.5425873 ],
#        [0.45501614],
#        [0.4170094 ],
#        [0.4495254 ],
#        [0.46940142],
#        [0.44783282],
#        [0.5180592 ],
#        [0.469716  ],
#        [0.49202257],
#        [0.4605295 ],
#        [0.5503316 ],
#        [0.5944771 ],
#        [0.7281313 ],
#        [0.61862046],
#        [0.6317004 ],
#        [0.5988786 ],
#        [0.65188026],
#        [0.6844449 ],
#        [0.73039246],
#        [0.6213609 ],
#        [0.5481365 ],
#        [0.5874342 ],
#        [0.6436881 ],
#        [0.71450835],
#        [0.57715595],
#        [0.614055  ],
#        [0.6494863 ],
#        [0.60492283],
#        [0.59550667],
#        [0.64732563],
#        [0.6350529 ],
#        [0.57451534],
#        [0.5171265 ],
#        [0.49841705],
#        [0.29756376],
#        [0.19860014],
#        [0.33369213],
#        [0.23938675],
#        [0.22139865],
#        [0.22936612],
#        [0.23817687],
#        [0.20977418],
#        [0.14802155],
#        [0.15724179],
#        [0.1133129 ],
#        [0.1884248 ],
#        [0.21500453],
#        [0.41252604],
#        [0.4570312 ],
#        [0.44108438],
#        [0.40925366],
#        [0.49216902],
#        [0.5583427 ],
#        [0.55514926],
#        [0.64657474],
#        [0.5390774 ],
#        [0.57598734],
#        [0.61670053],
#        [0.63843215],
#        [0.64081454],
#        [0.6758628 ],
#        [0.7600382 ],
#        [0.76872814],
#        [0.7900769 ],
#        [0.7644866 ],
#        [0.74985063],
#        [0.79200566],
#        [0.8469062 ],
#        [0.79070526],
#        [0.76124483],
#        [0.8148235 ],
#        [0.83444977],
#        [0.7955673 ],
#        [0.7915343 ],
#        [0.77141804]], dtype=float32)

# %%
# hasil prediksi pada setiap langkah waktu
inv_test_X= scaler.inverse_transform(new_test_X)

for i in range(len(inv_test_X)):
    print("X=%s, Predicted= %s" % (inv_test_X[i], inv_predict[i]))
# X=[8600. 8775. 8800. 8575. 8600.], Predicted= 8651.467061042786
# X=[8500. 8600. 8650. 8500. 8500.], Predicted= 8541.875264048576
# X=[8525. 8425. 8550. 8350. 8525.], Predicted= 8484.427425265312
# X=[8625. 8500. 8675. 8450. 8625.], Predicted= 8588.905841112137
# X=[8625. 8600. 8700. 8550. 8625.], Predicted= 8627.177047729492
# X=[8575. 8550. 8625. 8425. 8575.], Predicted= 8551.356184482574
# X=[8500. 8625. 8650. 8500. 8500.], Predicted= 8543.49189400673
# X=[8550. 8400. 8600. 8350. 8550.], Predicted= 8504.265168309212

# %%
# menghitung nilai RMSE dan Mape pada hasil prediksi
rmse = sqrt(mean_squared_error(inv_predict, inv_actual))
print('Test RMSE: %.2f' % rmse)
mape = np.mean(np.abs((inv_actual - inv_predict)/inv_actual))*100
print(f'Test MAPE: {np.round(mape, 2)} %')
# Out:
# Test RMSE: 145.99
# Test MAPE: 1.26 %

# %%
# insert nilai tanggal, aktual, prediksi
test = dataset.drop(dataset.index[0])
test.insert(1, "Prediction", inv_predict.ravel(), True)
#test.insert(1, "Difference", test["Prediction"] - test["Actual"], True)

# %%
# perbandingan hasil pengujian dan prediksi
test = pd.DataFrame(test, columns = ["Date", "Close", "Prediction"])
test["RMSE"] = test.apply(lambda x: mean_squared_error(test.loc[:x.name, 'Close'].tolist(), test.loc[:x.name, 'Prediction'].tolist(), squared=False), axis = 1)
test["MAPE"] = test.apply(lambda x: np.mean(np.abs((test.loc[:x.name, 'Close'].tolist() - test.loc[:x.name, 'Prediction'])/test.loc[:x.name, 'Close'].tolist()))*100, axis=1)
test.to_csv("M:/Metopen/save/hasil_prediksi_bm_rv.csv", index=False)
print(test)
# Out:
#           Date  Close   Prediction        RMSE      MAPE
# 1   2021-12-23   7075  7109.022391   34.022391  0.480882
# 2   2021-12-24   7050  7151.705885   75.834063  0.961759
# 3   2021-12-27   7000  7101.017463   85.061033  1.122208
# 4   2021-12-28   7050  7074.976110   74.716036  0.930224
# 5   2021-12-29   7100  7097.378680   66.838335  0.751563
# ..         ...    ...          ...         ...       ...
# 160 2022-08-24   8625  8588.905841  147.242475  1.276761
# 161 2022-08-25   8575  8627.177048  146.842077  1.272610
# 162 2022-08-26   8500  8551.356184  146.443756  1.268484
# 163 2022-08-29   8550  8543.491894  145.994741  1.261169
# 164 2022-08-30   8650  8504.265168  145.993157  1.263752
#
# [164 rows x 5 columns]

# %% [markdown]
# # Visualisasi Data

# %%
# visualisasi data
fig, ax1 = plt.subplots(figsize=(22, 10), sharex=True)
xt = test["Date"]
yt = test[["Close", "Prediction"]]
plt.title("Bank Mandiri", fontsize= 25)
plt.plot(xt, yt["Close"])
plt.ylabel("Close", fontsize= 16)
plt.xlabel("Date", fontsize= 16)
plt.plot(xt, yt["Prediction"])
plt.legend(["Close","Prediction"], loc="upper left")
plt.savefig('M:/Metopen/save/hasil_prediksi_bm_rv.jpg', format='jpg', dpi=1000)

#plt.grid()
plt.show()
